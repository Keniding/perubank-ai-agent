# %% [markdown]
# # PeruBank AI Agent - Demo Notebook
# ## AMD Developer Hackathon 2026 | Team LEAD
#
# This notebook demonstrates the multi-agent banking system running on AMD MI300X.

# %%
import httpx

response = httpx.get("http://localhost:8000/v1/models")
print(response.json())
